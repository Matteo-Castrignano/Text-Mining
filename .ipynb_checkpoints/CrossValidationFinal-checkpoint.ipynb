# %%
import csv
import matplotlib.pyplot as plt
import nltk
import pandas
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import cross_val_score, cross_val_predict
import numpy as np
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.metrics import plot_confusion_matrix, f1_score
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import cross_validate
from time import time
# import nltk
# nltk.download('stopwords')

pandas.set_option('display.max_rows', 1000)

# loading the dataset
dataset = pandas.read_csv("training_set.csv",sep=',',usecols=['tweet','label'])
dataset.tweet=dataset.tweet.str.lower()
print(f"Number of tweets: {len(dataset)}")
display(dataset)
# Out:
# Number of tweets: 594
#                                                  tweet  label
# 0    vaccini il successo della brexit premettera ag...      2
# 1    vaccini mentre l eu cerca tra l altro senza su...      2
# 2    si andrebbe presumibilmente ben oltre l anno a...      1
# 3    oggi 30 gennaio ho ricevuto la seconda dose de...      1
# 4    vaccini una discussione da riaprire la specula...      2
# 5    in realta soprattutto nel caso di confronto co...      2
# 6    quale sarebbe il vantaggio del nuovo vaccino t...      2
# 7     sono infermiera da 40 anni e sai quanti ne ho...      0
# 8    vaccino vaccini vaccinocovid mammamia bambini ...      0
# 9     1 eu ha firmato accordi con almeno 6 potenzia...      2
# 10    dipende cosa succedera se avremo una variante...      1
# 11    da mesi faccio questa domanda ma nessuno dico...      2
# 12    hanno vaccinato persone che non erano in list...      1
# 13    il piano di vaccinazione non esiste hanno sol...      0
# 14    alla meta delle persone oggetto di ricerca ve...      2
# 15   boom di focolai tra gli anziani dopo il vaccin...      0
# 16    johnson amp johnson stima che potrebbero esse...      2
# 17   novartis come sanofi produrra il vaccino pfize...      1
# 18   vaccino covid alta probabilita che diventi ine...      2
# 19    e tutti i milioni di vaccini gia comprati noi...      2
# 20   prima del covid conte premier molti con le pez...      2
# 21   era questo il piano di bill gates o ricordo ma...      0
# 22   in campania chi ha piu di 80 anni puo prenotar...      1
# 23   non capisco io so di persone over 55 che hanno...      2
# 24    prof secondo lei non avrebbe senso investire ...      1
# 25   aifa autorizza vaccino astrazeneca dai 18aa co...      2
# 26    non dimentichiano che questo vaccino potrebbe...      1
# 27    autorizza il vaccino astrazeneca ma ne raccom...      2
# 28    piu o meno lo stesso tempo che ha bisogno il ...      2
# 29    o che dice il prof galli mentre ci sono diver...      0
# 30   la cts suggerisce un utilizzo preferenziale de...      2
# 31    tutti i vaccini sono una mezza sola a livello...      2
# 32    che in italia si tolleri il conflitto di inte...      2
# 33    invece che inseguire l approvazione di reithe...      1
# 34   3 una ue lungimirante avrebbe potuto investire...      2
# 35   covid vaccini pfizer e moderna efficacia vacci...      1
# 36    tanto questa bolla dei vaccini esplodera a br...      0
# 37    siamo costretti a puntare tutto sul vaccino e...      2
# 38   son perplesso sulle limitazioni dell aifa su v...      1
# 39    stai confondendo i dati di fase iii con quell...      1
# 40    la diversa efficacia dei vaccini approvati re...      2
# 41    vaccinazioni sembra lo spot della bigpharma a...      2
# 42    errore clamoroso non aver appoggiato in modo ...      2
# 43   inoltre l articolo afferma che l autorita pale...      2
# 44    che se pensiamo di utilizzare solo i vaccini ...      1
# 45    e una cosa normale l immunita di gregge e a s...      0
# 46    tu che invece hai capito tutto spiegaci sulla...      2
# 47    semplice nel mio territorio il 24 per cento d...      2
# 48   covid19 prima immunita di gregge col vaccino o...      2
# 49   liguria toti e fondamentale proteggere al piu ...      1
# 50    covid 19 vaccini e assurdo nonostante le case...      0
# 51    legga cosa ha scritto il prof tra i tanti a p...      1
# 52    io non mi vaccino xche i vaccini influenzali ...      0
# 53    saro ignorante in tema di vaccini ma questo d...      0
# 54   ah era lotteriascontrini avevo sentito lotteri...      2
# 55    ma non sarebbe stato meglio e piu utile spend...      1
# 56    noi invece con due vaccini efficaci andiamo a...      2
# 57   lo spot pro vaccino di tornatore da come l ide...      2
# 58   qualcuno sa perche non si investe in produzion...      2
# 59   codacons aprire indagine su fornitura vaccini ...      2
# 60   ma questi furbetti i vaccini se li sono fatti ...      2
# 61    bene cosi seguira una causa legale in cui si ...      0
# 62    se cosi e assurdo l avesse fatto arcuri lo av...      2
# 63   marshillblog post sull ue e il suo obiettivo s...      2
# 64   essere vaccination sara un privilegio che dara...      2
# 65   coronavirus cosa dice la legge in caso di rita...      2
# 66    per esportare i vaccini fuori dall unione eur...      2
# 67    no generalmente chi muore dopo il vaccino muo...      0
# 68    non sono assolutamente un novax ma sembra che...      2
# 69    astrazeneca non e efficace come pfizer e mode...      1
# 70   per un acceleratore di particelle abbiamo buca...      2
# 71   vaccino adesso che i vaccini sono arrivati e q...      2
# 72   se vogliamo investire nella ricerca sui vaccin...      2
# 73   questo lo dovremmo sapere tutti posiamo rifiut...      0
# 74    la vaccinata che contrae il virus si ammali a...      2
# 75    il problema x me non sara a chi somministrare...      2
# 76   rapporto 1 2 di infettati tra vaccinati e grup...      2
# 77   la strategia vaccino buona o cattiva non e il ...      2
# 78   ultimati i test per il vaccino novavax perfett...      1
# 79   abbiamo notizie del pianovaccini c e il cronop...      2
# 80    almeno per quello chebriguarda i vaccini ad m...      0
# 81    e se nel frattempo le industrie militari le s...      2
# 82    io grazie al vaccino contro il morbillo ho gu...      2
# 83    c era da aspettarselo che con la pandemia e i...      2
# 84    strategicamente penso che produrre un vaccino...      1
# 85    senza contare che il lockdown inprimavera qui...      2
# 86    la risposta alla seconda dose e piu vigorosa ...      1
# 87    cosa state ricercando che non sia vaccino non...      0
# 88    io oenso che con efficacia cosi diversa dei n...      1
# 89    az ha detto che ha dei problemi di produzione...      2
# 90   due vaccini esistono gia perche testarne altri...      1
# 91   e poi i furbetti del vaccino italia non ti sme...      2
# 92    vaccini occidentali versus vaccino russi fors...      2
# 93    i studi certificano che il vaccino russo e pi...      2
# 94    comunque una cosa non mi e ben chiara stanno ...      0
# 95    la diversa efficacia dei vari vaccini approva...      2
# 96    finora non ci sono vaccini per i minori di 16...      2
# 97   lineanotte ma perche non ce li rendete adesso ...      1
# 98   primum vivere se i nuovi vaccini annullano la ...      2
# 99    ti suggerisco di vedere un posti di dove spie...      0
# 100  non e accettabile che ci vogliono tenere chius...      2
# 101   l addetto stampa del pentagon john kirby affe...      2
# 102   il comitato scientifico tedesco per i vaccini...      2
# 103   1 non e un vaccino ma una terapia genetica 2 ...      0
# 104  l unione europea ha pubblicato gli accordi con...      1
# 105  posso dire occhio al sudafrica che da li potre...      2
# 106   i vaccini non vanno solo al personale sanitar...      1
# 107   ma no perche se il vaccino e efficace e una o...      1
# 108   tralasciando le perplessita etiche della vice...      2
# 109   pero pensa che brutto sapere che a molti di n...      0
# 110  l italia sta uscendo dalla emr3ge3nza grazie a...      0
# 111   la diversa efficacia dei vari vaccini approva...      2
# 112  un po di verita su vaccini e covid19 vaccino v...      2
# 113   una puttanata questo vaccino che copre solo i...      2
# 114  ottima notizia oggi l agenzia europea del farm...      1
# 115  vaccini covid_19 quale sara il vaccino superst...      1
# 116   e poi ribadisco il vaccino astrazeneca ne ave...      2
# 117   ma io mi faccio solo una domanda ma visto che...      1
# 118   ma io vorrei capire la logica che ci ha porta...      2
# 119  italiani brava gente over 350 000 imbucati del...      2
# 120  quindi il vaccino dell allievo di burioni astr...      2
# 121   e solo una coincidenza i vaccini di qualsiasi...      2
# 122  somministrazione di un vaccino elaborato in so...      1
# 123  fra non molto dovrebbe essere approvato anche ...      2
# 124   e allora faremo le brigate resistenza al vacc...      0
# 125   infatti aggiungi i dubbi etici su una sperime...      2
# 126  dunque dosi di vaccino date a personale non sa...      2
# 127   il comitato scientifico tedesco per i vaccini...      2
# 128   sono assolutamente a favore dei vaccini e non...      1
# 129   mi ha un po deluso la copertura poi in realta...      2
# 130  non sono d accordo mi terrei aperto a tutti i ...      2
# 131  e evidente l inferiorita dei vaccini con vetto...      2
# 132  non sarebbe possibile fare qualcosa di simile ...      1
# 133  ma l ema autorizza i vaccini solo in base alle...      2
# 134  l efficacia del 60 vicino al 100 sulle manifes...      1
# 135  ema approva vaccino astrazeneca sicurezza simi...      2
# 136  dopo tante polemiche da l ok al vaccino di poc...      2
# 137   gent ma prof ssa per i vaccini con efficacia ...      2
# 138   il virus non sparisce col vaccino e poi non t...      0
# 139   lo so per questo e assurdo vote vaccinarci tu...      0
# 140   un vaccino che purtroppo servira a poco speri...      2
# 141   non tutta questa meraviglia ma di certo pense...      2
# 142   prof quanto pensa che possa durare la sommini...      1
# 143   buona notizia pero mi lascia molto perplesso ...      2
# 144  uno dei vaccini su cui l italia punta di piu i...      0
# 145  perche gli stati uniti pfizer e la germania bi...      2
# 146  mio padre ha 86 anni e sta da dio superando an...      1
# 147  muore dopo il vaccino un caso vaccino vaccinaz...      0
# 148  la divina commedia insegna reazione chimica nu...      0
# 149   cioe lei pensa che speranza di testa sua deci...      2
# 150  arcuri moderna non ci dara le 160 000 dosi di ...      2
# 151  ma col vaccino di johnson amp johnson ci si pu...      2
# 152  ogni giorno nasce un vaccino la terza guerra m...      0
# 153   news flash news euronews rss vaccini pubblica...      2
# 154   non sono un esperta ma dovrebbe essere comunq...      2
# 155   signori il vaccino non vi serve biden ha avut...      2
# 156  vaccini pierpaolo sileri  ben vengano lo sputn...      1
# 157   se vaccini il tizio nella linea coi clienti d...      1
# 158   risultati fase 3 del vaccino jannsen efficaci...      1
# 159  anche il vaccino johnson amp johnson e meno ef...      2
# 160  sono davvero molto amareggiato abbiamo finalme...      1
# 161  arcuri abbaia ma anche sui vaccini ha commesso...      2
# 162   non c e niente da sapere e una cosa ovvia per...      2
# 163   eticamente accettabile significa che data la ...      2
# 164   si dovra chiarire prima o poi chi ha elaborat...      2
# 165  covid mancano i vaccini e gia fiorisce il merc...      2
# 166   tutto da leggere i vaccini astrazeneca sono s...      2
# 167  e una vergogna istituzionale non ci sono neanc...      2
# 168  certo tasse e vaccini che bello scenario il va...      0
# 169   sono convinto che se scambiassimo mimmo con m...      2
# 170   quindi non sono vaccini hai presente il vacci...      1
# 171  vero che il vaccino novavax potrebbe reagire m...      2
# 172  ma quelli che voi cattivi libberisti che compr...      2
# 173   voglio capire come lo testano se in fase 3 ci...      2
# 174  l america del tanto osannato biden fa pagare i...      2
# 175   ma volete ficcarvi in testa che questi di pfi...      0
# 176  e il fato come quando un bimbo smette di parla...      0
# 177  come fare scelte efficaci ed eque l europa vac...      1
# 178   no perche bisogna accelerare e i vaccini che ...      1
# 179   non credo perche questo e un vaccino diverso ...      1
# 180  e la guerra fredda sui vaccini vaccino astraze...      2
# 181  moriro di fame ma ridendo dei scemi che se lo ...      0
# 182   sulla mascherina mi sa che ha ragione e sa da...      1
# 183   lui lo sa a chi servono i vaccini tanto se de...      2
# 184   1 perche la ricerca locale di un vaccino e de...      1
# 185   probabilmente non si aspettavano tutta questa...      1
# 186   quanto costano finiranno come i 400 milioni b...      2
# 187  come giustamente ha detto i vaccini che funzio...      2
# 188   gibilterra in nessun altro luogo relazione co...      0
# 189  dopo i protocolli errati nella cura il sito de...      0
# 190   italia prima in eu per n vaccini prima dello ...      2
# 191   ma quanta disinformazione il vaccino infallib...      0
# 192   a proposito di vaccini in lombardia fontana h...      2
# 193  vaccini ci e stato venduto lo scenario miglior...      0
# 194   la virologa antonella viola ha detto che il v...      2
# 195   invece di investire sulla produzione italiana...      2
# 196  400 000 furbetti del vaccino andateliacercare ...      2
# 197  il comitato sui vaccini del robert koch instit...      0
# 198   ci sono delle cose strane nei vaccini ma in t...      0
# 199  considerato che per l ennesima volta regionelo...      2
# 200  dovresti resistere ai vaccini covid 19 le vacc...      0
# 201   forse ue ha sbagliato approccio ai vaccini ma...      1
# 202  l ue si lamenta che una societa farmaceutica b...      2
# 203   io sono favorevole ai vaccini hanno salvato l...      1
# 204  la comunicazione scientifica e importante perc...      1
# 205  siccome non si riescono ad avere abbastanza do...      2
# 206   dovrebbero dare buone ragioni per cominciare ...      2
# 207  case report di me medesimo 2 a 48 ore dalla se...      1
# 208  il comitato scientifico tedesco per i vaccini ...      0
# 209   mi date un parere su questa novita freschissi...      2
# 210   fanno finta di rispettare le liberta la verit...      0
# 211  macerata una casa di riposo modello nessun con...      0
# 212   si ho un appuntamento per il 23 febbraio sper...      1
# 213   abbiamo due vaccini con efficacia altissima d...      2
# 214   per un buon vaccino ci vogliono dai 3 ai 5 an...      0
# 215  molti merdosi fanno i furbi pure con i vaccini...      2
# 216  casualmente e atteso per domani il via libera ...      2
# 217   lei lo ha detto che e scettica a fare il vacc...      1
# 218  la pubblicita tv del governodicialtroni riguar...      2
# 219   probabilmente fra 3 4 mesi avremo almeno un v...      2
# 220   penso che servirebbero davvero delle operazio...      2
# 221  mio padre i vaccini fanno maleeee mia zia io h...      0
# 222  in italia non arrivano i vaccini pfizer con te...      2
# 223   mi pare di capire che non e molto chiaro cosa...      1
# 224   basta guardare i fatti ci si scanna su covid ...      2
# 225  lo sdegno contro i novax e una colossale arma ...      2
# 226   ecco le sciocchezze che divulgano senza basi ...      1
# 227  la jena suggerisce di provare il vaccino russo...      2
# 228   i ragazzi non possono farci nulla intanto in ...      2
# 229  petizione europea ufficiale per i vaccini libe...      1
# 230   si ma sabin regalo il vaccino qui c e un merc...      2
# 231  vaccino pfizer la fonte conferma chi subisce d...      0
# 232  e potrebbe essere anche una opportunita ma ho ...      2
# 233   ema sta valutando anche il dossier con il vac...      2
# 234   quelle infezioni nel gruppo placebo sono per ...      2
# 235   no guarda che molti sono anche morti e non si...      0
# 236  a me non interessa che il vaccino sia made in ...      1
# 237   del resto le sperimentazioni dei vaccini attu...      2
# 238   una possibilita potrebbe essere quella di con...      1
# 239   gestendo male l approvvigionamento dei vaccin...      2
# 240  acivicduty i vaccini sono stati finanziati con...      2
# 241   _al momento _ dal punto di vista etico sarebb...      1
# 242  l imperial college accantona lo sviluppo del s...      2
# 243   ancheio ho i miei dubbi su questo vaccini vol...      0
# 244   la memoria e un vaccino guarda caso anche le ...      0
# 245  secondo me tante persone stanno facendo il vac...      2
# 246   my famiglia ed io fatto 3 mesi fa vaccino pne...      2
# 247   dai dati analizzati dal prof bucci nn sembra ...      0
# 248   ma lei sa cosa c e dietro la produzuione deii...      2
# 249  bastardi ci hanno messo il cappio al collo il ...      0
# 250   bene allora riconvertiamo le fabbriche che fa...      0
# 251   si intende un vaccino in grado di contrastare...      1
# 252  un bicchiere di vino senza vaccino albano ospi...      0
# 253  lo ha deciso il cts che a sua volta e in mano ...      2
# 254   quali nostre cure vaccini non ne abbiamo e oe...      1
# 255  linee cellulari per vaccini feti senzienti sez...      0
# 256   ti vedo molto attento sulle tematiche dei vac...      2
# 257   potra essere una buona idea destinare il vacc...      2
# 258   e le tv e giornalai pagati al soldo continuan...      0
# 259   che cazzo di vaccino e se va ripetuto ogni an...      0
# 260   come si puo fare dei vaccini se nel contratto...      0
# 261  lesioni da vaccino 3 prep act protezione della...      0
# 262   magari per colpa dei no vax e cosi vaccino pe...      2
# 263   se e dico se i vaccini vanno bene anche quand...      2
# 264  ehh la folla chiede i vaccini non gliene frega...      0
# 265   ma giordano non doveva tranquillizzare albano...      0
# 266   e molto peggio e un puttanata senza precedent...      2
# 267   covid_19 variantebrasiliana abruzzo vaccino p...      0
# 268   la sua affermazione mi fa sorridere in rete t...      0
# 269   ovvio i morti di qualsiasi cosa sono morti di...      0
# 270   io ho fatto tutti i vaccini del mondo sia chi...      0
# 271   ok ma i vaccini non sono tutti uguali e fonda...      2
# 272  non faro il vaccino pero mi chiedo quelli che ...      0
# 273   se penso che il vaccino ha bisogno di tempo p...      2
# 274   anche nell ipotesi fantascientifica che il va...      0
# 275   non si tratta di essere primi o secondi stiam...      1
# 276   su quali vaccini io non ho nessuna titubanza ...      1
# 277  se per contrastare il virus l unica e il lockd...      1
# 278  il ha una pagina dove vengono spiegati tutti i...      2
# 279   pero udo mi faccio una domanda il presidente ...      2
# 280   e indietro rispetto ai tempi previsti se non ...      1
# 281  io la vedo cosi considerando che l apparato sa...      0
# 282  questi bastardi ci mettono sotto ricatto se no...      0
# 283   1 se sono tutti vaccinati il virus non avra p...      1
# 284  non sono favorevole o contraria a priori ai va...      0
# 285   se e per questo anche il virus del papilloma ...      1
# 286   come sarebbe a dire non risulta i vaccini han...      1
# 287   l immunizzazione con un vaccino che esprime l...      0
# 288   la conta del vaccino e importante e nel corso...      1
# 289  il capitalismo e sbagliato ma il vaccino mrna ...      1
# 290   sono d accordo per questo devono sbrigarsi a ...      1
# 291   gia ed e altrettanto buono che finalmente ci ...      1
# 292   non avrebbe dovuto essere una sorpresa esegui...      2
# 293   peccato che gli unici vaccini approvati siano...      2
# 294   un vaccino che funziona al 95 e infatti mirac...      1
# 295     i vaccini sono velenosi non faccia il vaccino       0
# 296  vaccino secondo i giornali in sicilia sono sta...      2
# 297   veramente io ho detto che lo stato dovrebbe c...      1
# 298   la mettiamo che un vaccino puo richiedere anc...      2
# 299   il vaccino serve a non avere problematiche gr...      2
# 300  ma sta ggente e evidente che non abbia fatto m...      2
# 301   sono d accordo ma se dobbiamo puntare tutto s...      1
# 302   onestamente non so se gallera e competente ce...      0
# 303   il vaccino minimo 15 giorni prima che faccia ...      2
# 304   io ne sono sicura e andata cosi per i vaccini...      2
# 305   i richiami si fanno su quelli gia vaccinati c...      2
# 306   se non dico una minchiata e mi pare di no il ...      2
# 307  vaccino c e un polemicone su chi li vuole fare...      1
# 308   un pensiero che ho avuto e che forse le autor...      0
# 309   tesoro allora non farti piu vaccini e non pre...      1
# 310   rispondo volentieri nel senso che sto pubblic...      2
# 311   senza l approvazione di altri vaccini pensiam...      2
# 312   idem fatti tutti i vaccini e me ne sono penti...      0
# 313   come si fa un vaccino muoiono o sono morte pe...      0
# 314   comunque per tutti i vaccini che ho fatto non...      2
# 315   io non capisco niente ma o 29 dicmebre o 15 g...      2
# 316   certo come nel 73 a napoli per vaccino colera...      2
# 317   esattamente cosi sono 70 anni che di cerca in...      2
# 318   non proprio il vaccino non e solo biontech ma...      2
# 319   aspetta i vaccini per il vaiolo la poliomenit...      0
# 320  nelle priorita per i vaccini ci metterei le ca...      1
# 321  ora basta ennesima notizia terroristica sull e...      2
# 322   cosa stabilire quali e dove saranno i punti d...      2
# 323   credo di si non farlo e un diritto costituzio...      2
# 324  la germania viaggia a quota 240 000 circa pers...      2
# 325  letteralmente tutta la comunita scientifica se...      0
# 326  invece di criticare gallera perche non critica...      2
# 327   io non sono assolutamente contraria ai vaccin...      0
# 328   sta scritto ovunque ma forse non non si capis...      0
# 329   peraltro sui vaccini sbaglia tutto i vaccini ...      2
# 330  prima di farvi iniettare nelle vene robe che n...      0
# 331   da quanto ho letto il vaccino necessita di mi...      2
# 332   mica tanto logico non mi pare che funzioni co...      0
# 333   e la mia domanda e sempre la stessa da mesi i...      1
# 334  per regione lombardia i vaccini sono arrivati ...      2
# 335   io non mi fido di chi viene pagato dai media ...      0
# 336   lo so che etichettare ti piace ma io ho sempr...      0
# 337   mai e stata fatta una vaccinazione di massa e...      2
# 338   mi raccomando tu il vaccino non farlo eh e or...      1
# 339   imposti poi come schemi rimediali fissi e mai...      0
# 340   auguriamoci che si possano trovare vaccini an...      2
# 341   dipendono dal virus 6 volte piu letale dell i...      1
# 342  mancano medici per fare i vaccini medici per f...      2
# 343  vaccini l italia va a rilento somministrata po...      2
# 344  domanda per i luminari della scienza se i proc...      0
# 345   punto 8 ma non preoccuparti il vaccino fatto ...      2
# 346  tutti quelli che hanno fatto il vaccino in dir...      0
# 347  470 000 dosi di vaccino e 35 000 somministrati...      2
# 348   non ci sono i vaccini e forse non ha capito c...      0
# 349  difficile spiegare ai tedeschi che c e un otti...      2
# 350  sulla sperimentazione dei vaccini e utile racc...      0
# 351   la risposta e molto piu semplice di cio che i...      0
# 352   il flop campagna vaccini si basa su dati cert...      2
# 353  si puo scegliere a quale vaccino sottoporsi no...      2
# 354   i paesi piu poveri rischiano di rimanere senz...      2
# 355  covid_19 mentre in europa iniziano le vaccinaz...      1
# 356   ma distribuiti a chi siamo l unica nazione ch...      2
# 357   il vaccino protegge dall evoluzione pericolos...      2
# 358   non credo sarebbe una discriminazione inaccet...      1
# 359   il problema non e il lockdown il problema e l...      2
# 360   i vaccini hanno salvato miliardi di persone m...      0
# 361  il vaccino az suscita perplessita per la sua s...      2
# 362   no perche esistono altri vaccini in commercio...      0
# 363   pierino come al solito non ha capito un caxxo...      0
# 364   la societa civile rispetta gli altri non si e...      2
# 365   mancano medici infermieri per iniettare i vac...      2
# 366   la sua e un opinione giustizialista detta da ...      0
# 367   nn mi fido di inniettarmi un vaccino che e st...      0
# 368   non credo che sia questione di propaganda ma ...      1
# 369   se poi ci saranno variazioni nel numero vacci...      2
# 370  come si fa a rendere obbligatorio un vaccino s...      2
# 371  un solo vaccino e siamo partiti da 3 giorni co...      2
# 372   certo se vaccini tutti e funziona non si infe...      0
# 373   e chi come me ha fatto tutti i vaccini compre...      0
# 374   grazie per il programma pillole di vaccino un...      2
# 375   i dati dicono che l italia e tra le prima 10 ...      2
# 376   stai tranquilla con la penuria di vaccini che...      2
# 377   faccio il vaccino da 20 anni e ho fatto quell...      0
# 378   semplicemente piu coglioni di noi ma lo volet...      1
# 379   i vaccini in realta servono a rendere piu dif...      1
# 380  l intervista di montanari rimossa da youtube i...      0
# 381   il mes cosa c entra con i vaccini esiste l es...      2
# 382  10 000 vaccini a settimana 40 000 al mese 120 ...      2
# 383   siete vergognosi e senza ritegno siete solo c...      2
# 384   c e stata una scelta politica di fondo nello ...      2
# 385   egregio se e vero il numero di morti giornali...      2
# 386   bisogna terrorizzare per bene la gente cosi s...      1
# 387   siete voi al governo dovevate trovare sommini...      2
# 388  ma se il vaccino non ferma la trasmissibilita ...      2
# 389   firma non preoccuparti sai quanti vaccini fac...      1
# 390   quelli che hanno dubbi sui vaccini esistono d...      2
# 391  la lombardia e la regione piu lenta nella somm...      1
# 392  roba da matti i vaccini sono arrivati dovremmo...      1
# 393   non so possibile che abbiano puntato tutto su...      2
# 394   invito te e tutti coloro che sostengono la te...      1
# 395   ma porca e da mesi che si sa che il vaccino e...      2
# 396   mi chiedo perche negare al personale sanitari...      2
# 397   ma non saprei io vivo a napoli faccio il vacc...      2
# 398   non hai capito come al solito sono due cose d...      0
# 399   preoccuparsi ma razionalmente c e un solo vac...      2
# 400  la nostra lombardia ha gia dimostrato con il v...      2
# 401   ogni anno faccio il vaccino antinfluenzale da...      1
# 402   leggendo i dati di oggi piuttosto peggiorati ...      1
# 403  la variante inglese e neutralizzata dalla risp...      1
# 404   le uniche conseguenze di un vaccino sono gli ...      1
# 405   dottore penso che la sua intelligenza debba l...      2
# 406   quando il vaccino sara disponibile per tutti ...      2
# 407   in verita su alcune riviste scientifiche si e...      2
# 408   e perche lo stesso obbligo non e stato fatto ...      0
# 409   il vaccino x quanto protegge non si sa i vacc...      0
# 410   se tu non ti vaccini il problema non e solo p...      1
# 411   ripeto che e tutto a livello teorico se lo st...      2
# 412  e passata la prima settimana ma i vaccinati so...      2
# 413   non e un vaccino destinato al commercio verra...      2
# 414   ministero salute e aifa attestano che non si ...      0
# 415   e come sappiamo i vaccini possono essere una ...      2
# 416   si faro il vaccino ho problemi di salute sono...      1
# 417  alla casa farmaceutica e stato dato un pacco d...      0
# 418  allora non e un vaccino il pazzo dr fauci ha d...      0
# 419   e l 1 circa troppo o nella media non so probl...      2
# 420   ottima elaborazione magari il dottor arcuri n...      1
# 421  raga io ve lo dico il 2021 andra esattamente c...      2
# 422  ore 13 36 46 030 vaccinati su 469 950 dosi con...      2
# 423  ma allora il vaccino a che serve voi scienziat...      1
# 424   questo non e un vaccino come tutti gli altri ...      0
# 425   magari non si fidano di quel vaccino specific...      2
# 426   lei ci prende in giro come conte allora la st...      0
# 427   e il momento di testimoniare la consapevolezz...      1
# 428   poco informata o sovrainformata per generare ...      2
# 429  letto lavori vaccini su nejm e lancet avrei fa...      1
# 430   tiffany_dover e cresce il numero di reazioni ...      0
# 431   in qualita di che cattedra in virologia lo de...      2
# 432  io sono della lombardia e gia non ho trovato v...      2
# 433   non capisco da dove provenga 8000 vaccini al ...      2
# 434   non ci sono vaccini sicuri come non ci sono m...      2
# 435   ma guardi che al momento non c e vaccino per ...      2
# 436   notizia vecchia e diversa da come descritta i...      2
# 437   mi possono anche mettere in galera ma io ques...      0
# 438   non facciamoci prendere dal panico fino a ier...      2
# 439  facciamo un po come cazzo ci pare vaccino lond...      2
# 440  ognuno fa le sue scelte sui vaccini io persona...      1
# 441   questa e una cazzata il vaccino antinfluenzal...      2
# 442   il vaccino va fatto senza remora alcuna colgo...      1
# 443   il governo con i vaccini prende per il culo c...      2
# 444   si perche basta capire come funzionano i vacc...      1
# 445   e poi cosa sappiamo di questi vaccini chi ha ...      2
# 446  sinceramente nonostante io sia pro vaccini ho ...      2
# 447   e un vaccino sperimentale per ora dicono dai ...      2
# 448   si perche i vaccini che abbiamo fatto da picc...      1
# 449   io mi vaccino contro l influenza da circa 25 ...      0
# 450  vaccini in lombardia nonostante la lombardia s...      2
# 451  perche si e cosi lenti con i vaccini perche in...      1
# 452   magari fosse solo il recovery il problema sia...      2
# 453   pero al momento ci sono ritardi proprio dall ...      2
# 454  il vaccino e stato fatto e autorizzato in meno...      0
# 455   sapete che la scienza e la ricerca hanno fatt...      2
# 456   terapia genica altro che vaccino c e forse ch...      0
# 457   l emergenza non sarebbe possibile provarla ne...      0
# 458   i vaccini tradizionali innescavano una malatt...      0
# 459  stamattina siamo alle 52ma minaccia di crisi d...      2
# 460   faranno quello che vogliono io non mi vaccino...      0
# 461  adesso bisogna accelerare le approvazioni dei ...      1
# 462   in sostanza ti accolli tutti i rischi e non p...      0
# 463   forse non ti e chiaro che il consenso informa...      0
# 464  vaccini in vaticano dalla seconda meta di genn...      2
# 465   si e ancora sigrazie ai vaccini viviamo megli...      1
# 466   ma quali vaccini non sara di sicuro un vaccin...      0
# 467  vaccini in questo paese non hanno ancora capit...      1
# 468   mamma mia che piagnisteo questi della setta e...      2
# 469  scommettiamo che faro prima a trovare il vacci...      1
# 470  uk in grossa difficolta su seconde dosi vaccin...      2
# 471   si sta facendo una folle informazione sulla s...      2
# 472  noi operatori sanitari oltre a lavorare fino a...      1
# 473  in 8 mesi gli scienziati hanno realizzato il v...      1
# 474  pfizerbiontech vaccino l olanda prende tempo p...      0
# 475   immagino che chi rifiuta il vaccino per coere...      0
# 476   ovvio devono spingere verso il vaccino se non...      2
# 477   ieri abbiamo inoculato 2 vaccini oggi 4 itali...      2
# 478   ehm lo sapete vero che tutti i vaccini copron...      2
# 479  da quando e immunologa da pure lezioni sui vac...      2
# 480  si fa uso di quel determinato vaccino i vecchi...      0
# 481  cari cittadini del mondo io non ho mai fatto v...      0
# 482   fino all esaurimento delle scorte dei vaccini...      2
# 483  thread vaccino i problemi nella fornitura di v...      2
# 484   anche i danni da pagare per gli effetti colla...      0
# 485   appena arriva il vaccino mi prendo pure il vo...      1
# 486  da report vaccini del governo dato allarmante ...      2
# 487  qui su twitter esistono 2 fazioni da un lato i...      1
# 488  dunque mia considerazione hanno iniziato oggi ...      1
# 489   le 450000 dosi dei vaccini sono arrivate alle...      2
# 490   io non sono novax ho tutti i vaccini in regol...      0
# 491  tralasciando il discorso vaccino si o no il no...      2
# 492  la storia delle pandemie dei vaccini e degli s...      1
# 493   il sudamerica si serve del vaccino cinese la ...      2
# 494   avere le idee chiare e i nervi saldi le masch...      2
# 495   non capisco ho letto in piu fonti autorevoli ...      2
# 496   un casco una patente seguire norme di pulizia...      0
# 497   vorrei farle una domanda i suoi dubbi sono so...      2
# 498   entro dieci anni chi si vaccina diviene un og...      0
# 499   il documento descritto come redatto da pfizer...      0
# 500  per segnalare la gestione vaccini in lombardia...      1
# 501   in tutta la cina hanno fatto 3 mln di vaccini...      2
# 502  sto seguendo la discussione sul numero di vacc...      2
# 503  in lombardia solo possibile prenotare vaccino ...      1
# 504  sul vaccino obbligatorio la parola spetta a gi...      1
# 505  il capo della biontech dice che servono altri ...      2
# 506   il vaccino russo che usa come vettore l adeno...      2
# 507   potrebbero anche mancare i soldi il vaccino d...      2
# 508   non hanno proprio fatto i tamponi si sono con...      2
# 509   proprio per questo non ci sono certezze matem...      2
# 510  c e qualcosa di buono in questa tipologia di v...      2
# 511  trovo la corsa al vaccino intesa come chi comi...      2
# 512  atteggiamento britannico logico tutti vaccini ...      1
# 513  mentre in italia si auto celebrano circa trent...      2
# 514   penso che sia il piano a regime con il solo v...      1
# 515   non sono un esperto ma mi sembra una cazzata ...      1
# 516   sottosegretario invece di parlarci dei concer...      2
# 517   presentano il vaccino come il messia ma non e...      2
# 518   ultimo paese per vaccini debito alle stelle p...      2
# 519   se e vero come sembra che l immunita attualme...      2
# 520  posso criticare pfizer per il loro egoismo sui...      1
# 521  preciso una cosa prima di continuare tutti i v...      1
# 522   potete fare pressione verso l ema per sblocca...      1
# 523  sono un medico e voglio vaccinarmi ma non sono...      1
# 524  facciamo due conti veloci popolazione italiana...      2
# 525  e attivo il sito web del dove monitorate lo st...      2
# 526   i vaccini con immunodeficienza o malattie aut...      2
# 527  lombardia ultima nei vaccini anti influenzali ...      2
# 528  la tedesca biontech lancia l allarme non ce la...      2
# 529  un idea per i nuovi vaccin se si potessero far...      2
# 530   tutto e relativo ma quel vaccino e gia stato ...      2
# 531  ma dopo il vaccino potro assembrarmi no potro ...      0
# 532   dovrebbe essere cosi non ci sarebbero stati q...      2
# 533   i vaccini con mrna sono allo studio dai primi...      2
# 534   non sono novax ma non ho alcuna fiducia in va...      0
# 535  si parla solo del vaccino come salvezza dell i...      2
# 536  e anche capodanno ce lo siamo levato dalca ora...      2
# 537   il punto piu insidioso dei no vax e invece pr...      2
# 538   il fatto e che questi anticovid sono stati sv...      0
# 539  biontech intende aumentare la produzione del v...      2
# 540  ma chi non vuole vaccinarsi che problemi ha pe...      2
# 541   ah certo il fallimento dei vaccini e colpa di...      2
# 542   intanto dovrebbero prima arrivare i vaccini  ...      2
# 543   lo dicono molteplici fatti per esempio basta ...      2
# 544  vaccini distretto bologna ieri mi hanno chiama...      1
# 545   il bello che neanche i vaccini possono coprir...      0
# 546   si vaccini e non rompa le balle se sara vacci...      0
# 547   certamente perche sono i governi che si sono ...      2
# 548   lo vedremo alla fine cmq secondo me borghi vo...      2
# 549  covid_19 pfizerbiotech da sole non riescono a ...      2
# 550  visti i recenti problemini dopo il vaccino pfi...      0
# 551  obbligarli non sara possibile pero al personal...      2
# 552   non sono contrario ai vaccini sia chiaro ma d...      0
# 553   normalmente un vaccino e sottoposto a test pe...      0
# 554   dobbiamo aspettare il vaccino per avere il pu...      2
# 555  le compagnie aeree stanno sperimentando le app...      2
# 556   risposta da covidiota copione le controindica...      0
# 557   ti ho risposto a quella affermazione il fatto...      1
# 558  ecco come funziona un vaccino sarscov2 l agent...      1
# 559   in cina non usano il vaccino pfizer ne quello...      2
# 560  biontech lancia l allarme servono altre dosi d...      2
# 561   una sequenza di ceppi come plasma oh vaccini ...      2
# 562  io che non vorrei fare i vaccini genici seguiv...      2
# 563  l intervista di montanari rimossa da youtube i...      0
# 564  allarme della tedesca biontech servono altri v...      2
# 565  ugur sahin biontech su der spiegel spiega come...      2
# 566   il vaccino tradizionale non ho parole ma se n...      2
# 567   mi chiedo pero se tu ti vaccini non dovresti ...      2
# 568   copiate distribuzione vaccino da israele i va...      2
# 569   visto che i produttori del vaccino e lo stato...      0
# 570   ma che domande sono metti che c e una fila di...      1
# 571   visto che il vaccino e in due dosi ci vuole u...      2
# 572   capisco male io o un vaccino al 60 avra un ap...      2
# 573   in realta anche il vaccino e un atto di carit...      1
# 574   3 tornando al tema vaccini al netto del tweet...      2
# 575   perche anziche puntare tutto sui vaccini non ...      2
# 576   ogni farmaco dall aspirina a salire puo avere...      1
# 577   me lo auguro anch io molti si sono stupiti de...      1
# 578  remuzzi istituto mario negri ecco perche il va...      2
# 579   liberissimi di non fare il vaccino ma se non ...      2
# 580  i cyber attacchi alla irbm di pomezia sono ini...      2
# 581  in italia credo che per fare il pieno di vacci...      2
# 582  lo esprimono dall alto della loro posizione po...      0
# 583   io non sono contro i vaccini ma se non ricord...      0
# 584  cio vuol dire che stanno gia mettendo a punton...      2
# 585   senza velleita di valenza statistica ma le 3 ...      0
# 586  i vaccini sono pochi quelli somministrati sono...      2
# 587   sei virologo hai degli studi scientifici che ...      1
# 588  uno si vaccina ed ecco ha portato via il vacci...      2
# 589   il problema e un altro il fatto che tu vaccin...      0
# 590   se una persona non lo vuole fare e solo perch...      2
# 591   che senso avrebbe questa distinzione per il v...      2
# 592   lei si vaccini e segua scrupolosamente le reg...      1
# 593  anticorpi monoclonali per accompagnare il vacc...      2

# %%
italian_stemmer = SnowballStemmer('italian')
class StemmedCountVectorizer(CountVectorizer):
    def build_analyzer(self):
        analyzer = super(StemmedCountVectorizer, self).build_analyzer()
        return lambda doc: ([italian_stemmer.stem(w) for w in analyzer(doc)])

# %%
folds = 10;
max_ngram = 2;
def benchmark(clf, ngram):
    print('_' * 80)
    print("Training:")
    print(f"{clf} with ngram = {ngram}")
    
    text_clf = Pipeline([
        ('vect', StemmedCountVectorizer(min_df=3, analyzer="word", stop_words = set(stopwords.words('italian')),ngram_range = ngram)),
        ('tfidf', TfidfTransformer(smooth_idf=True,use_idf=True)),
        ('clf', clf),
    ])
    
    t0 = time()
    predicted = cross_val_predict(text_clf, dataset.tweet, dataset.label, cv=folds)
    t1 = time()
    t = (t1-t0)/10
    conf_matrix = confusion_matrix(dataset.label, predicted, labels = [0,1,2])
    report = classification_report(dataset.label, predicted, output_dict=True)
    report["conf_matrix"] = conf_matrix
    report["time"] = t
    print(report)
    output = {}
    output["classifier"] = clf
    output["ngram"] = ngram
    output["scores"] = report
    
    return output

results = []
for clf in (
        (svm.LinearSVC()),
        (AdaBoostClassifier()),
        (KNeighborsClassifier(n_neighbors=5)),
        (DecisionTreeClassifier()),
        (RandomForestClassifier()),
        (MultinomialNB()),
        (BernoulliNB())):
    results.append(benchmark(clf, (1,1)))
    
"""for clf in (
        (svm.LinearSVC()),
        (AdaBoostClassifier()),
        (KNeighborsClassifier(n_neighbors=5)),
        (RandomForestClassifier()),
        (MultinomialNB()),
        (BernoulliNB())):
    results.append(benchmark(clf, (1,2)))"""
# Out:
# ________________________________________________________________________________
# Training:
# LinearSVC() with ngram = (1, 1)
# {'0': {'precision': 0.40625, 'recall': 0.37142857142857144, 'f1-score': 0.3880597014925374, 'support': 140}, '1': {'precision': 0.3181818181818182, 'recall': 0.208955223880597, 'f1-score': 0.2522522522522523, 'support': 134}, '2': {'precision': 0.6111111111111112, 'recall': 0.721875, 'f1-score': 0.66189111747851, 'support': 320}, 'accuracy': 0.5235690235690236, 'macro avg': {'precision': 0.4451809764309764, 'recall': 0.43408626510305615, 'f1-score': 0.43406769040776655, 'support': 594}, 'weighted avg': {'precision': 0.4967456552052511, 'recall': 0.5235690235690236, 'f1-score': 0.5049416121277446, 'support': 594}, 'conf_matrix': array([[ 52,  23,  65],
#        [ 24,  28,  82],
#        [ 52,  37, 231]], dtype=int64), 'time': 0.46495885848999025}
# ________________________________________________________________________________
# Training:
# AdaBoostClassifier() with ngram = (1, 1)
# {'0': {'precision': 0.3333333333333333, 'recall': 0.2, 'f1-score': 0.25, 'support': 140}, '1': {'precision': 0.234375, 'recall': 0.11194029850746269, 'f1-score': 0.15151515151515152, 'support': 134}, '2': {'precision': 0.5829596412556054, 'recall': 0.8125, 'f1-score': 0.6788511749347259, 'support': 320}, 'accuracy': 0.51010101010101, 'macro avg': {'precision': 0.38355599152964626, 'recall': 0.37481343283582086, 'f1-score': 0.3601221088166258, 'support': 594}, 'weighted avg': {'precision': 0.44548821863377164, 'recall': 0.51010101010101, 'f1-score': 0.45881381528980236, 'support': 594}, 'conf_matrix': array([[ 28,  25,  87],
#        [ 20,  15,  99],
#        [ 36,  24, 260]], dtype=int64), 'time': 0.5708729028701782}
# ________________________________________________________________________________
# Training:
# KNeighborsClassifier() with ngram = (1, 1)
# {'0': {'precision': 0.4625, 'recall': 0.5285714285714286, 'f1-score': 0.49333333333333335, 'support': 140}, '1': {'precision': 0.3142857142857143, 'recall': 0.2462686567164179, 'f1-score': 0.27615062761506276, 'support': 134}, '2': {'precision': 0.6382978723404256, 'recall': 0.65625, 'f1-score': 0.6471494607087828, 'support': 320}, 'accuracy': 0.5336700336700336, 'macro avg': {'precision': 0.47169452887537994, 'recall': 0.47703002842928216, 'f1-score': 0.472211140552393, 'support': 594}, 'weighted avg': {'precision': 0.5237703785576125, 'recall': 0.5336700336700336, 'f1-score': 0.5272031619425851, 'support': 594}, 'conf_matrix': array([[ 74,  19,  47],
#        [ 29,  33,  72],
#        [ 57,  53, 210]], dtype=int64), 'time': 0.436832332611084}
# ________________________________________________________________________________
# Training:
# DecisionTreeClassifier() with ngram = (1, 1)
# {'0': {'precision': 0.4125874125874126, 'recall': 0.42142857142857143, 'f1-score': 0.41696113074204955, 'support': 140}, '1': {'precision': 0.208, 'recall': 0.19402985074626866, 'f1-score': 0.2007722007722008, 'support': 134}, '2': {'precision': 0.5920245398773006, 'recall': 0.603125, 'f1-score': 0.5975232198142415, 'support': 320}, 'accuracy': 0.468013468013468, 'macro avg': {'precision': 0.4042039841549044, 'recall': 0.4061944740582801, 'f1-score': 0.4050855171094973, 'support': 594}, 'weighted avg': {'precision': 0.4631011624965892, 'recall': 0.468013468013468, 'f1-score': 0.4654637433466651, 'support': 594}, 'conf_matrix': array([[ 59,  28,  53],
#        [ 28,  26,  80],
#        [ 56,  71, 193]], dtype=int64), 'time': 0.46595211029052735}
# ________________________________________________________________________________
# Training:
# RandomForestClassifier() with ngram = (1, 1)
# {'0': {'precision': 0.5058823529411764, 'recall': 0.30714285714285716, 'f1-score': 0.3822222222222222, 'support': 140}, '1': {'precision': 0.15, 'recall': 0.022388059701492536, 'f1-score': 0.03896103896103895, 'support': 134}, '2': {'precision': 0.5766871165644172, 'recall': 0.88125, 'f1-score': 0.6971569839307787, 'support': 320}, 'accuracy': 0.5521885521885522, 'macro avg': {'precision': 0.4108564898351979, 'recall': 0.40359363894811656, 'f1-score': 0.37278008170467997, 'support': 594}, 'weighted avg': {'precision': 0.4637431089433976, 'recall': 0.5521885521885522, 'f1-score': 0.47444802220494864, 'support': 594}, 'conf_matrix': array([[ 43,   4,  93],
#        [ 17,   3, 114],
#        [ 25,  13, 282]], dtype=int64), 'time': 0.7049111366271973}
# ________________________________________________________________________________
# Training:
# MultinomialNB() with ngram = (1, 1)
# {'0': {'precision': 0.6666666666666666, 'recall': 0.15714285714285714, 'f1-score': 0.2543352601156069, 'support': 140}, '1': {'precision': 0.6, 'recall': 0.022388059701492536, 'f1-score': 0.04316546762589928, 'support': 134}, '2': {'precision': 0.5611510791366906, 'recall': 0.975, 'f1-score': 0.7123287671232876, 'support': 320}, 'accuracy': 0.5673400673400674, 'macro avg': {'precision': 0.6092725819344524, 'recall': 0.3848436389481165, 'f1-score': 0.33660983162159797, 'support': 594}, 'weighted avg': {'precision': 0.5947839708031554, 'recall': 0.5673400673400674, 'f1-score': 0.45342813898570294, 'support': 594}, 'conf_matrix': array([[ 22,   0, 118],
#        [  5,   3, 126],
#        [  6,   2, 312]], dtype=int64), 'time': 0.4380263090133667}
# ________________________________________________________________________________
# Training:
# BernoulliNB() with ngram = (1, 1)

# %%
print(results)
print(len(results))
print(type(results))
#print((results[0][2]))

# %%
import pandas as pd

def makeHistogram(results):
    column_size = 0.05
    indices = np.arange(len(results))

    clf_names = [x["classifier"] for x in results]
    ngram = [x["ngram"] for x in results]
    scores = [x["scores"] for x in results]
    #print(scores)
    
    #plotting time and accuracy
    plt.figure(figsize=(16, 8))
    plt.title("Accuracy and training time")
    plt.bar(indices, [s["time"] for s in scores], column_size, label="time", color='navy')
    plt.bar(indices + .2, [s["accuracy"] for s in scores], column_size, label="accuracy", color='lightgreen')
    plt.xticks(())
    plt.legend(loc='best')
    
    for i, c in zip(indices, clf_names):
        plt.text(i, -.1, str(c) + "\n" + str(ngram[i]))

    plt.show()
    
    #plotting precision and recall scores for each class
    plt.figure(figsize=(16, 8))
    plt.title("Precision and recall per class")
    
    plt.bar(indices, [s["0"]["precision"] for s in scores], column_size, label="precision", color='c')
    plt.bar(indices + .2, [s["1"]["precision"] for s in scores], column_size, color='c')
    plt.bar(indices +.4, [s["2"]["precision"] for s in scores], column_size, color='c')
    
    plt.bar(indices + .05, [s["0"]["recall"] for s in scores], column_size, label="recall", color='lightgreen')
    plt.bar(indices + .25, [s["1"]["recall"] for s in scores], column_size, color='lightgreen')
    plt.bar(indices + .45, [s["2"]["recall"] for s in scores], column_size, color='lightgreen')
    
    plt.xticks(())
    plt.legend(loc='best')
    
    for i, c in zip(indices, clf_names):
        plt.text(i, -.1, str(c) + "\n" + str(ngram[i]))
        
    for i in indices:
        plt.text(i, -.05, "0")
        plt.text(i + .2, -.05, "1")
        plt.text(i + .4, -.05, "2")

    plt.show()
    
makeHistogram(results)

# %%
# code for custom stop words
stop_words = [x.strip() for x in open('stopWords.txt','r').read().split('\n')]

folds = 10
print('NAIVE BAYES CLASSIFIER - CUSTOM STOP WORDS')
for i in range(max_ngram):
    for j in range(max_ngram):
        if j>= i :
            text_clf = Pipeline([
                ('vect', StemmedCountVectorizer(min_df=2, analyzer="word", strip_accents = "unicode", stop_words = stop_words, ngram_range = (i+1,j+1))),
                ('tfidf', TfidfTransformer(smooth_idf=True,use_idf=True)),
                ('clf', MultinomialNB()),
            ])
            scores = cross_validate(text_clf, dataset.tweet, dataset.label, cv=folds, scoring = scoring)
            print(f"------- ngram = {(i+1,j+1)} -------")
            print_metrics(scores)
